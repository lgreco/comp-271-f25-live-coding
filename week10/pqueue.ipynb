# %%
class Node:
    def __init__(self, value: str):
        self.value = value
        self.right = None
        self.left = None

# %%
from dataclasses import dataclass


@dataclass
class Node:
    value: str
    left: Node | None
    right: Node | None

# %%
def left_child(parent: int) -> int:
    """Left child of binary node in array representatio is given
    $$ \text{left}(\text{parent}) = 2 \cdot \text{parent} + 1 $$
    """
    return 2 * parent + 1


def right_child(parent: int) -> int:
    return 2 * parent + 2
    # return 2*(parent+1)
    # return left(parent)+1


def parent(child: int) -> int:
    if child > 0:
        return (child - 1) // 2
    else:
        return None


def violates_heap_property(index: int) -> bool:
    """Determine if a "node" at position index violates the heap property
    because it's not >= than both its children. THIS IS PSEUDOCODE AND SO
    IT VIOLATES THE PROGRAMMERS PACT
    """
    if (
        underlying[index] < underlying[left_child(index)]
        or underlying[index] < underlying[right_child(index)]
    ):
        return True
    else:
        return False

# %% [markdown]
# ![18th century adjacency matrix](https://drive.google.com/uc?export=view&id=1rHp2CcI88eM00glxJWIvAKKLeBosapdD)
#
# *1740 [de Leth](https://nl.wikipedia.org/wiki/Hendrik_de_Leth) distance table between cities in the Lower Countries (Netherlands and Belgium, today).*
#
# ---
#
# # Simple Graphs
#
#
# Given an adjacency matrix
#
# ```python
# G: list[list[int]]
# ```
#
# for an undirected graph
#
# ## Describe the graph
#
# Write a method `describe` that outputs (prints) the following information:
#
# - the number of vertices in the graph
# - the number of edges in the graph
# - the shortest edge
# - the longest edge
#
# Method `describe` _should_ call other method(s) to obtain the necessary information.
#
# ## Find the most popular vertex
#
# Write a method `find_popular` that returns the index of the vertex with the most neighbors.
#
# # Write a simple `Graph` class with the following functionality:
#
# - instantiate a graph with a specified number of vertices; if no number is give, the default should be 4.
# - its text representation (`__str__`) is based on the earlier `describe` method
# - `add_edge(u, v, weight)` to add an edge between vertices `u` and `v` with the specified non-negative `weight`
# - `adjust_edge(u, v, weight)` to channge the weight of an edge between vertices `u` and `v` to the specified non-negative `weight`
# - `remove_edge(u, v)` to remove an edge between vertices `u` and `v`
# - `exists_edge(u, v)` to tell if an edge between vertices `u` and `v` exists or not
#
# # Requirements
#
# * Imported modules like `numpy` cannot be used for this assignment.
# * Treat lists as arrays: do not use list methods like `append`, `pop`, `index`, etc.
# * Access and assignment of vaues in an array should be done only with indexed references, for example `array[1][2]=3`.
# * List comprehension cannot be used except to initialize vectors/matrices as shown below.
# * An array with $m$ rows and $n$ columns can be initialized as<br/>
# `array = [[some_value for _ in range(n)] for _ in range(m)]`
# * You may not use the statements `break` and `continue`
# * Methods that return a value should have one and only one `return` statement.
# * Object fields must be property named to indicate privacy (using single or double underscores).
# * No magic values.
# * Comments and docstrings required.
# * Code must be efficient. Duplicate code (ie the same code in two or more methods) should be avoided.
# * Line length limited to 80 characters.
#
# # Reading
#
# - [Chapters 1 and 2](https://learning.oreilly.com/library/view/graph-algorithms/9781492047674/) from Graph Algorithms, by Mark Needham and Amy E. Hodler. Free from the O'Reilly platform with LUC email login.
#
# - [Part I](https://learning.oreilly.com/library/view/graph-algorithms-the/9781098182519/xhtml/part1.xhtml) from
#   Graph Algorithms the Fun Way, by Jeremy Kubica. Free from the O'Reilly platform with LUC email login.
#
# - [Chapter 14](https://learning.oreilly.com/library/view/data-structures/9780134855912/ch14.xhtml#ch14lev1sec1) from
#   Data Structures & Algorithms in Python by John Canning et al. Free from the O'Reilly platform with LUC email login.
